# %%
import pandas as pd
from futu import *

# %%
tickers = [2,5,8,11,12,16,66,293,388,823,1299,2318,2388,2778,2800]

# %%
for i in range(0, len(tickers)):
    tickers[i] = 'HK.' + str(tickers[i]).zfill(5)

# %%
tickers
# Out:
# ['HK.00002',
#  'HK.00005',
#  'HK.00008',
#  'HK.00011',
#  'HK.00012',
#  'HK.00016',
#  'HK.00066',
#  'HK.00293',
#  'HK.00388',
#  'HK.00823',
#  'HK.01299',
#  'HK.02318',
#  'HK.02388',
#  'HK.02778',
#  'HK.02800']

# %%
quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)

# %%
df = quote_ctx.get_market_snapshot(tickers)

# %%
df[1]
# Out:
#         code          update_time  last_price  open_price  high_price  \
# 0   HK.00002  2019-08-07 16:08:50       85.10       83.35       85.15
# 1   HK.00005  2019-08-07 16:08:50       60.20       60.00       60.35
# 2   HK.00008  2019-08-07 16:08:50        4.34        4.37        4.38
# 3   HK.00011  2019-08-07 16:08:50      173.00      173.50      174.30
# 4   HK.00012  2019-08-07 16:08:50       37.80       38.50       38.55
# 5   HK.00016  2019-08-07 16:08:50      111.80      114.10      114.10
# 6   HK.00066  2019-08-07 16:08:50       48.55       49.30       49.50
# 7   HK.00293  2019-08-07 16:08:50       10.40       10.40       10.44
# 8   HK.00388  2019-08-07 16:08:50      246.60      243.20      246.80
# 9   HK.00823  2019-08-07 16:08:50       91.55       91.10       91.90
# 10  HK.01299  2019-08-07 16:08:50       76.80       75.70       76.80
# 11  HK.02318  2019-08-07 16:08:50       88.25       89.00       89.00
# ...

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
quote_ctx.close()
